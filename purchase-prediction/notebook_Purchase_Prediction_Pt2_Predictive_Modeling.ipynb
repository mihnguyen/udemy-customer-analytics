# %% [markdown]
# <a href="https://colab.research.google.com/github/mihnguyen/udemy-customer-analytics/blob/main/purchase-prediction/notebook_Purchase_Prediction_Pt2_Predictive_Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook is part 2 and a continuation of the [[Udemy CAiP] Purchase Prediction Pt1 - Descriptive Analysis notebook](https://colab.research.google.com/drive/1Acmi4BOuO1V7LCxbnMCVzu46vFSpftA6#scrollTo=97I0svM77BjK&uniqifier=1).
# While part 1 is descriptive analysis, part 2 will concern predictive modeling.

# %% [markdown]
# ###Import Libraries

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

import pickle

from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ###Import Purchase Data

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-06c9ad68-a02d-4f2e-aeac-99bbc7cde56e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-06c9ad68-a02d-4f2e-aeac-99bbc7cde56e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving purchase data.csv to purchase data.csv

# %%
import io
df_purchase = pd.read_csv(io.BytesIO(uploaded['purchase data.csv']))

# %% [markdown]
# ###Import Pickle Objects

# %%
# Import pickle objects
from google.colab import drive
drive.mount('/content/drive')

import pickle
drive.mount('/content/drive')
DATA_PATH = "/content/drive/My Drive/Colab Notebooks"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
infile = open(DATA_PATH+'/pca.pickle','rb')
pca = pickle.load(infile)

pca
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
infile = open(DATA_PATH+'/scaler.pickle','rb')
scaler = pickle.load(infile)

scaler
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
infile = open(DATA_PATH+'/kmeans_pca.pickle','rb')
kmeans_pca = pickle.load(infile)

kmeans_pca
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
# Standardize data
features = df_purchase[['Sex', 'Marital status', 'Age', 'Education', 'Income', 'Occupation', 'Settlement size']]
df_purchase_segm_std = scaler.transform(features)

# Apply PCA
df_purchase_segm_pca = pca.transform(df_purchase_segm_std)

# Segment data
purchase_segm_kmeans_pca = kmeans_pca.predict(df_purchase_segm_pca)

# Create copy of dataframe
df_purchase_predictors = df_purchase.copy()

# Add segment labels
df_purchase_predictors['Segment'] = purchase_segm_kmeans_pca
segment_dummies = pd.get_dummies(purchase_segm_kmeans_pca, prefix = 'Segment', prefix_sep = '_')
df_purchase_predictors = pd.concat([df_purchase_predictors, segment_dummies], axis = 1)

df_pa = df_purchase_predictors

# %% [markdown]
# ###Modeling Purchase Probability

# %% [markdown]
# Now we will calculate the probability of a customer purchasing at each shop visit. Method used is Logistic Regression.
#
# First, define the dependent and independent variables.
#
# Dependent variable is whether a purchase happens or not (values are either 0 or 1).
#
# As for independent variable, common sense is that price has the most correlation to purchase. So price is the first independent variable. Here let's use the mean price (of all 5 brands) as the independent variable:

# %%
Y = df_pa['Incidence']

# %%
X = pd.DataFrame()
X['Mean Price'] = (df_pa['Price_1'] +
                   df_pa['Price_2'] +
                   df_pa['Price_3'] +
                   df_pa['Price_4'] +
                   df_pa['Price_5'] ) / 5

# %% [markdown]
# Now fit model to predic purchase probability:

# %%
model_purchase = LogisticRegression(solver = 'sag') # 'sag' was chosen as the solver as it's optimal for simple problem with large dataset like this one
model_purchase.fit(X, Y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='sag', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# Now check the exact relationship between (Mean) Price (X) and Purchase Probability (Y) using coefficient for the independent variable (coef_ attribute), which is the mean price:

# %%
model_purchase.coef_
# Out:
# array([[-2.34802882]])

# %% [markdown]
# The coefficient for mean price = -2.35. This indicates that an increase in price will result in a decrease in purchase probability (obviously). However, this coefficient only shows the direction of the relationship (which in this case is reverse, or negative).
#
# Next, let's quantify the magnitude of the negative relationship between mean price and purchase probability.

# %% [markdown]
# ###Modeling Price Elasticity of Purchase Probability

# %% [markdown]
# The purpose of this modeling is to check the effect of various mean prices on the purchase probability. Various mean prices here can be done by generating a range of mean price values. How to determine that range?
#
# First, by checking the 5 prices (Price_1 to Price_5) to see their distributions. This checking can be done through .describe() function:

# %%
df_pa[['Price_1', 'Price_2', 'Price_3', 'Price_4', 'Price_5']].describe()
# Out:
#             Price_1       Price_2       Price_3       Price_4       Price_5
# count  58693.000000  58693.000000  58693.000000  58693.000000  58693.000000
# mean       1.392074      1.780999      2.006789      2.159945      2.654798
# std        0.091139      0.170868      0.046867      0.089825      0.098272
# min        1.100000      1.260000      1.870000      1.760000      2.110000
# 25%        1.340000      1.580000      1.970000      2.120000      2.630000
# 50%        1.390000      1.880000      2.010000      2.170000      2.670000
# 75%        1.470000      1.890000      2.060000      2.240000      2.700000
# max        1.590000      1.900000      2.140000      2.260000      2.800000

# %% [markdown]
# The minimum price is 1.10 (min Price_1), while the maximum price is 2.80 (max Price_5).
#
# Then, the range of mean price we could pick is, say 0.50 to 3.50, for example. Now let's generate a range of numbers between 0.5 and 3.5, with steps = 0.01 to denote an increase in 1 cent (an increase in 1% of a dollar):

# %%
price_range = np.arange(0.5, 3.5, 0.01)
price_range
# Out:
# array([0.5 , 0.51, 0.52, 0.53, 0.54, 0.55, 0.56, 0.57, 0.58, 0.59, 0.6 ,
#        0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.7 , 0.71,
#        0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.8 , 0.81, 0.82,
#        0.83, 0.84, 0.85, 0.86, 0.87, 0.88, 0.89, 0.9 , 0.91, 0.92, 0.93,
#        0.94, 0.95, 0.96, 0.97, 0.98, 0.99, 1.  , 1.01, 1.02, 1.03, 1.04,
#        1.05, 1.06, 1.07, 1.08, 1.09, 1.1 , 1.11, 1.12, 1.13, 1.14, 1.15,
#        1.16, 1.17, 1.18, 1.19, 1.2 , 1.21, 1.22, 1.23, 1.24, 1.25, 1.26,
#        1.27, 1.28, 1.29, 1.3 , 1.31, 1.32, 1.33, 1.34, 1.35, 1.36, 1.37,
#        1.38, 1.39, 1.4 , 1.41, 1.42, 1.43, 1.44, 1.45, 1.46, 1.47, 1.48,
#        1.49, 1.5 , 1.51, 1.52, 1.53, 1.54, 1.55, 1.56, 1.57, 1.58, 1.59,
#        1.6 , 1.61, 1.62, 1.63, 1.64, 1.65, 1.66, 1.67, 1.68, 1.69, 1.7 ,
#        1.71, 1.72, 1.73, 1.74, 1.75, 1.76, 1.77, 1.78, 1.79, 1.8 , 1.81,
#        1.82, 1.83, 1.84, 1.85, 1.86, 1.87, 1.88, 1.89, 1.9 , 1.91, 1.92,
#        1.93, 1.94, 1.95, 1.96, 1.97, 1.98, 1.99, 2.  , 2.01, 2.02, 2.03,
#        2.04, 2.05, 2.06, 2.07, 2.08, 2.09, 2.1 , 2.11, 2.12, 2.13, 2.14,
#        2.15, 2.16, 2.17, 2.18, 2.19, 2.2 , 2.21, 2.22, 2.23, 2.24, 2.25,
#        2.26, 2.27, 2.28, 2.29, 2.3 , 2.31, 2.32, 2.33, 2.34, 2.35, 2.36,
#        2.37, 2.38, 2.39, 2.4 , 2.41, 2.42, 2.43, 2.44, 2.45, 2.46, 2.47,
#        2.48, 2.49, 2.5 , 2.51, 2.52, 2.53, 2.54, 2.55, 2.56, 2.57, 2.58,
#        2.59, 2.6 , 2.61, 2.62, 2.63, 2.64, 2.65, 2.66, 2.67, 2.68, 2.69,
#        2.7 , 2.71, 2.72, 2.73, 2.74, 2.75, 2.76, 2.77, 2.78, 2.79, 2.8 ,
#        2.81, 2.82, 2.83, 2.84, 2.85, 2.86, 2.87, 2.88, 2.89, 2.9 , 2.91,
#        2.92, 2.93, 2.94, 2.95, 2.96, 2.97, 2.98, 2.99, 3.  , 3.01, 3.02,
#        3.03, 3.04, 3.05, 3.06, 3.07, 3.08, 3.09, 3.1 , 3.11, 3.12, 3.13,
#        3.14, 3.15, 3.16, 3.17, 3.18, 3.19, 3.2 , 3.21, 3.22, 3.23, 3.24,
#        3.25, 3.26, 3.27, 3.28, 3.29, 3.3 , 3.31, 3.32, 3.33, 3.34, 3.35,
#        3.36, 3.37, 3.38, 3.39, 3.4 , 3.41, 3.42, 3.43, 3.44, 3.45, 3.46,
#        3.47, 3.48, 3.49])

# %% [markdown]
# That's 300 generated values for mean price.
#
# Now store this range in dataframe called df_price_range:

# %%
df_price_range = pd.DataFrame(price_range)

# %% [markdown]
# Predict the purchase probability for each mean price (each of the generated prices above):

# %%
Y_pr = model_purchase.predict_proba(df_price_range)
Y_pr
# Out:
# array([[0.08204028, 0.91795972],
#        [0.08382601, 0.91617399],
#        [0.08564699, 0.91435301],
#        [0.08750375, 0.91249625],
#        [0.08939682, 0.91060318],
#        [0.09132675, 0.90867325],
#        [0.09329408, 0.90670592],
#        [0.09529934, 0.90470066],
#        [0.09734308, 0.90265692],
#        [0.09942583, 0.90057417],
#        [0.10154812, 0.89845188],
#        [0.1037105 , 0.8962895 ],
#        [0.1059135 , 0.8940865 ],
#        [0.10815765, 0.89184235],
#        [0.11044348, 0.88955652],
#        [0.1127715 , 0.8872285 ],
#        [0.11514225, 0.88485775],
#        [0.11755623, 0.88244377],
#        [0.12001395, 0.87998605],
#        [0.12251593, 0.87748407],
#        [0.12506265, 0.87493735],
#        [0.12765461, 0.87234539],
#        [0.13029229, 0.86970771],
#        [0.13297616, 0.86702384],
#        [0.13570669, 0.86429331],
#        [0.13848434, 0.86151566],
#        [0.14130954, 0.85869046],
#        [0.14418273, 0.85581727],
#        [0.14710433, 0.85289567],
#        [0.15007475, 0.84992525],
#        [0.15309439, 0.84690561],
#        [0.15616362, 0.84383638],
#        [0.15928281, 0.84071719],
#        [0.16245231, 0.83754769],
#        [0.16567245, 0.83432755],
#        [0.16894354, 0.83105646],
#        [0.17226589, 0.82773411],
#        [0.17563976, 0.82436024],
#        [0.17906541, 0.82093459],
#        [0.18254308, 0.81745692],
#        [0.18607299, 0.81392701],
#        [0.18965531, 0.81034469],
#        [0.19329023, 0.80670977],
#        [0.19697788, 0.80302212],
#        [0.20071838, 0.79928162],
#        [0.20451181, 0.79548819],
#        [0.20835826, 0.79164174],
#        [0.21225774, 0.78774226],
#        [0.21621027, 0.78378973],
#        [0.22021582, 0.77978418],
#        [0.22427435, 0.77572565],
#        [0.22838577, 0.77161423],
#        [0.23254997, 0.76745003],
#        [0.2367668 , 0.7632332 ],
#        [0.24103607, 0.75896393],
#        [0.24535758, 0.75464242],
#        [0.24973107, 0.75026893],
#        [0.25415627, 0.74584373],
#        [0.25863285, 0.74136715],
#        [0.26316045, 0.73683955],
#        [0.2677387 , 0.7322613 ],
#        [0.27236715, 0.72763285],
#        [0.27704534, 0.72295466],
#        [0.28177276, 0.71822724],
#        [0.28654888, 0.71345112],
#        [0.29137312, 0.70862688],
#        [0.29624485, 0.70375515],
#        [0.30116341, 0.69883659],
#        [0.30612812, 0.69387188],
#        [0.31113823, 0.68886177],
#        [0.31619297, 0.68380703],
#        [0.32129153, 0.67870847],
#        [0.32643306, 0.67356694],
#        [0.33161667, 0.66838333],
#        [0.33684142, 0.66315858],
#        [0.34210636, 0.65789364],
#        [0.34741048, 0.65258952],
#        [0.35275274, 0.64724726],
#        [0.35813207, 0.64186793],
#        [0.36354735, 0.63645265],
#        [0.36899745, 0.63100255],
#        [0.37448118, 0.62551882],
#        [0.37999732, 0.62000268],
#        [0.38554464, 0.61445536],
#        [0.39112185, 0.60887815],
#        [0.39672765, 0.60327235],
#        [0.4023607 , 0.5976393 ],
#        [0.40801964, 0.59198036],
#        [0.41370307, 0.58629693],
#        [0.41940958, 0.58059042],
#        [0.42513773, 0.57486227],
#        [0.43088605, 0.56911395],
#        [0.43665306, 0.56334694],
#        [0.44243725, 0.55756275],
#        [0.44823709, 0.55176291],
#        [0.45405105, 0.54594895],
#        [0.45987756, 0.54012244],
#        [0.46571507, 0.53428493],
#        [0.47156198, 0.52843802],
#        [0.4774167 , 0.5225833 ],
#        [0.48327764, 0.51672236],
#        [0.48914318, 0.51085682],
#        [0.49501171, 0.50498829],
#        [0.50088161, 0.49911839],
#        [0.50675128, 0.49324872],
#        [0.51261908, 0.48738092],
#        [0.51848341, 0.48151659],
#        [0.52434264, 0.47565736],
#        [0.53019519, 0.46980481],
#        [0.53603944, 0.46396056],
#        [0.54187381, 0.45812619],
#        [0.54769672, 0.45230328],
#        [0.5535066 , 0.4464934 ],
#        [0.5593019 , 0.4406981 ],
#        [0.56508109, 0.43491891],
#        [0.57084264, 0.42915736],
#        [0.57658505, 0.42341495],
#        [0.58230686, 0.41769314],
#        [0.58800659, 0.41199341],
#        [0.59368281, 0.40631719],
#        [0.59933412, 0.40066588],
#        [0.60495912, 0.39504088],
#        [0.61055648, 0.38944352],
#        [0.61612484, 0.38387516],
#        [0.62166293, 0.37833707],
#        [0.62716947, 0.37283053],
#        [0.63264322, 0.36735678],
#        [0.63808298, 0.36191702],
#        [0.64348758, 0.35651242],
#        [0.6488559 , 0.3511441 ],
#        [0.65418681, 0.34581319],
#        [0.65947927, 0.34052073],
#        [0.66473224, 0.33526776],
#        [0.66994473, 0.33005527],
#        [0.67511579, 0.32488421],
#        [0.68024451, 0.31975549],
#        [0.68532999, 0.31467001],
#        [0.69037141, 0.30962859],
#        [0.69536797, 0.30463203],
#        [0.70031889, 0.29968111],
#        [0.70522346, 0.29477654],
#        [0.71008099, 0.28991901],
#        [0.71489083, 0.28510917],
#        [0.71965239, 0.28034761],
#        [0.72436508, 0.27563492],
#        [0.72902838, 0.27097162],
#        [0.7336418 , 0.2663582 ],
#        [0.73820487, 0.26179513],
#        [0.74271719, 0.25728281],
#        [0.74717837, 0.25282163],
#        [0.75158807, 0.24841193],
#        [0.75594598, 0.24405402],
#        [0.76025182, 0.23974818],
#        [0.76450536, 0.23549464],
#        [0.76870639, 0.23129361],
#        [0.77285475, 0.22714525],
#        [0.77695029, 0.22304971],
#        [0.78099292, 0.21900708],
#        [0.78498255, 0.21501745],
#        [0.78891915, 0.21108085],
#        [0.7928027 , 0.2071973 ],
#        [0.79663321, 0.20336679],
#        [0.80041074, 0.19958926],
#        [0.80413535, 0.19586465],
#        [0.80780715, 0.19219285],
#        [0.81142625, 0.18857375],
#        [0.81499281, 0.18500719],
#        [0.81850701, 0.18149299],
#        [0.82196903, 0.17803097],
#        [0.8253791 , 0.1746209 ],
#        [0.82873747, 0.17126253],
#        [0.83204439, 0.16795561],
#        [0.83530014, 0.16469986],
#        [0.83850504, 0.16149496],
#        [0.84165939, 0.15834061],
#        [0.84476354, 0.15523646],
#        [0.84781783, 0.15218217],
#        [0.85082264, 0.14917736],
#        [0.85377836, 0.14622164],
#        [0.85668538, 0.14331462],
#        [0.85954411, 0.14045589],
#        [0.86235498, 0.13764502],
#        [0.86511842, 0.13488158],
#        [0.86783489, 0.13216511],
#        [0.87050484, 0.12949516],
#        [0.87312874, 0.12687126],
#        [0.87570706, 0.12429294],
#        [0.87824028, 0.12175972],
#        [0.88072892, 0.11927108],
#        [0.88317345, 0.11682655],
#        [0.88557439, 0.11442561],
#        [0.88793225, 0.11206775],
#        [0.89024754, 0.10975246],
#        [0.89252079, 0.10747921],
#        [0.89475253, 0.10524747],
#        [0.89694327, 0.10305673],
#        [0.89909355, 0.10090645],
#        [0.90120391, 0.09879609],
#        [0.90327489, 0.09672511],
#        [0.90530701, 0.09469299],
#        [0.90730082, 0.09269918],
#        [0.90925686, 0.09074314],
#        [0.91117566, 0.08882434],
#        [0.91305777, 0.08694223],
#        [0.91490372, 0.08509628],
#        [0.91671406, 0.08328594],
#        [0.91848931, 0.08151069],
#        [0.92023002, 0.07976998],
#        [0.92193671, 0.07806329],
#        [0.92360992, 0.07639008],
#        [0.92525018, 0.07474982],
#        [0.926858  , 0.073142  ],
#        [0.92843391, 0.07156609],
#        [0.92997844, 0.07002156],
#        [0.93149209, 0.06850791],
#        [0.93297538, 0.06702462],
#        [0.93442881, 0.06557119],
#        [0.93585289, 0.06414711],
#        [0.93724813, 0.06275187],
#        [0.938615  , 0.061385  ],
#        [0.93995401, 0.06004599],
#        [0.94126564, 0.05873436],
#        [0.94255037, 0.05744963],
#        [0.94380867, 0.05619133],
#        [0.94504102, 0.05495898],
#        [0.94624789, 0.05375211],
#        [0.94742972, 0.05257028],
#        [0.94858699, 0.05141301],
#        [0.94972013, 0.05027987],
#        [0.95082959, 0.04917041],
#        [0.95191581, 0.04808419],
#        [0.95297922, 0.04702078],
#        [0.95402024, 0.04597976],
#        [0.95503931, 0.04496069],
#        [0.95603683, 0.04396317],
#        [0.95701322, 0.04298678],
#        [0.95796887, 0.04203113],
#        [0.95890419, 0.04109581],
#        [0.95981957, 0.04018043],
#        [0.9607154 , 0.0392846 ],
#        [0.96159205, 0.03840795],
#        [0.96244991, 0.03755009],
#        [0.96328934, 0.03671066],
#        [0.9641107 , 0.0358893 ],
#        [0.96491435, 0.03508565],
#        [0.96570065, 0.03429935],
#        [0.96646993, 0.03353007],
#        [0.96722255, 0.03277745],
#        [0.96795884, 0.03204116],
#        [0.96867912, 0.03132088],
#        [0.96938373, 0.03061627],
#        [0.97007297, 0.02992703],
#        [0.97074716, 0.02925284],
#        [0.97140661, 0.02859339],
#        [0.97205163, 0.02794837],
#        [0.9726825 , 0.0273175 ],
#        [0.97329953, 0.02670047],
#        [0.97390299, 0.02609701],
#        [0.97449317, 0.02550683],
#        [0.97507034, 0.02492966],
#        [0.97563478, 0.02436522],
#        [0.97618676, 0.02381324],
#        [0.97672652, 0.02327348],
#        [0.97725434, 0.02274566],
#        [0.97777046, 0.02222954],
#        [0.97827513, 0.02172487],
#        [0.97876859, 0.02123141],
#        [0.97925108, 0.02074892],
#        [0.97972283, 0.02027717],
#        [0.98018407, 0.01981593],
#        [0.98063503, 0.01936497],
#        [0.98107592, 0.01892408],
#        [0.98150697, 0.01849303],
#        [0.98192838, 0.01807162],
#        [0.98234036, 0.01765964],
#        [0.98274311, 0.01725689],
#        [0.98313683, 0.01686317],
#        [0.98352172, 0.01647828],
#        [0.98389797, 0.01610203],
#        [0.98426577, 0.01573423],
#        [0.98462529, 0.01537471],
#        [0.98497673, 0.01502327],
#        [0.98532025, 0.01467975],
#        [0.98565604, 0.01434396],
#        [0.98598425, 0.01401575],
#        [0.98630506, 0.01369494],
#        [0.98661862, 0.01338138],
#        [0.9869251 , 0.0130749 ],
#        [0.98722465, 0.01277535],
#        [0.98751742, 0.01248258],
#        [0.98780357, 0.01219643],
#        [0.98808323, 0.01191677],
#        [0.98835656, 0.01164344],
#        [0.9886237 , 0.0113763 ],
#        [0.98888477, 0.01111523],
#        [0.98913992, 0.01086008],
#        [0.98938927, 0.01061073],
#        [0.98963296, 0.01036704],
#        [0.98987111, 0.01012889],
#        [0.99010384, 0.00989616]])

# %% [markdown]
# That's an array with 300 rows (corresponding to 300 generated values for mean price), and 2 columns: the first column indicates the probability of no purchase, the second column the probability of purchase. Obviously, the lower the price, the higher the purchase probability.
#
# Let's store it in a variable called purchase_pr:

# %%
purchase_pr = Y_pr[:][:, 1]

# %% [markdown]
# Now, in order to answer how purchase probability changes with a given change in price, we'll calculate the price elasticities. Let's recall the definition of price elasticity:
#
# <img src="https://drive.google.com/uc?id=11cndOhtTFcAknIIhpE30UaG-2qmhpiHH" height="100">
#
# The simplified formula for the formula above is:
# E = beta * price * (1 - Pr(purchase))
#
# Following that simplified formula, let's create the variable price_elasticity that calculates the price elasticity at each price point:
# - price_elasticity is an array with shape of 1 x number of features. In this case, the number of features = 1. Therefore, to access the price coefficient, the index is [0].
# - The price is contained in price_range variable.
# - Pr(purchase) is purchase_pr.

# %%
price_elasticity = model_purchase.coef_[:, 0] * price_range * (1 - purchase_pr)

# %% [markdown]
# Now, let's create the dataframe df_price_elasticities to store all price elasticities:

# %%
df_price_elasticities = pd.DataFrame(price_range)

# %%
df_price_elasticities = df_price_elasticities.rename(columns = {0: "Price Point"})
df_price_elasticities['Mean Price Elasticity'] = price_elasticity

pd.options.display.max_rows = None # to see all rows
df_price_elasticities
# Out:
#      Price Point  Mean Price Elasticity
# 0           0.50              -0.096316
# 1           0.51              -0.100381
# 2           0.52              -0.104573
# 3           0.53              -0.108894
# 4           0.54              -0.113349
# 5           0.55              -0.117941
# 6           0.56              -0.122672
# 7           0.57              -0.127546
# 8           0.58              -0.132567
# 9           0.59              -0.137738
# 10          0.60              -0.143063
# 11          0.61              -0.148544
# 12          0.62              -0.154187
# 13          0.63              -0.159993
# 14          0.64              -0.165968
# 15          0.65              -0.172114
# 16          0.66              -0.178436
# 17          0.67              -0.184937
# 18          0.68              -0.191621
# 19          0.69              -0.198493
# 20          0.70              -0.205555
# 21          0.71              -0.212813
# 22          0.72              -0.220270
# 23          0.73              -0.227929
# 24          0.74              -0.235796
# 25          0.75              -0.243874
# 26          0.76              -0.252167
# 27          0.77              -0.260680
# 28          0.78              -0.269416
# 29          0.79              -0.278380
# 30          0.80              -0.287576
# 31          0.81              -0.297008
# 32          0.82              -0.306681
# 33          0.83              -0.316597
# 34          0.84              -0.326763
# 35          0.85              -0.337182
# 36          0.86              -0.347857
# 37          0.87              -0.358794
# 38          0.88              -0.369997
# 39          0.89              -0.381469
# 40          0.90              -0.393214
# 41          0.91              -0.405238
# 42          0.92              -0.417543
# 43          0.93              -0.430134
# 44          0.94              -0.443015
# 45          0.95              -0.456190
# 46          0.96              -0.469662
# 47          0.97              -0.483436
# 48          0.98              -0.497515
# 49          0.99              -0.511902
# 50          1.00              -0.526603
# 51          1.01              -0.541619
# 52          1.02              -0.556955
# 53          1.03              -0.572613
# 54          1.04              -0.588598
# 55          1.05              -0.604912
# 56          1.06              -0.621558
# 57          1.07              -0.638540
# 58          1.08              -0.655860
# 59          1.09              -0.673520
# 60          1.10              -0.691524
# 61          1.11              -0.709874
# 62          1.12              -0.728572
# 63          1.13              -0.747620
# 64          1.14              -0.767021
# 65          1.15              -0.786775
# 66          1.16              -0.806886
# 67          1.17              -0.827354
# 68          1.18              -0.848181
# 69          1.19              -0.869368
# 70          1.20              -0.890916
# 71          1.21              -0.912826
# 72          1.22              -0.935099
# 73          1.23              -0.957734
# 74          1.24              -0.980733
# 75          1.25              -1.004094
# 76          1.26              -1.027820
# 77          1.27              -1.051907
# 78          1.28              -1.076358
# 79          1.29              -1.101169
# 80          1.30              -1.126342
# 81          1.31              -1.151873
# 82          1.32              -1.177763
# 83          1.33              -1.204009
# 84          1.34              -1.230610
# 85          1.35              -1.257563
# 86          1.36              -1.284866
# 87          1.37              -1.312517
# 88          1.38              -1.340514
# 89          1.39              -1.368852
# 90          1.40              -1.397530
# 91          1.41              -1.426543
# 92          1.42              -1.455889
# 93          1.43              -1.485563
# 94          1.44              -1.515562
# 95          1.45              -1.545881
# 96          1.46              -1.576516
# 97          1.47              -1.607463
# 98          1.48              -1.638717
# 99          1.49              -1.670272
# 100         1.50              -1.702125
# 101         1.51              -1.734269
# 102         1.52              -1.766699
# 103         1.53              -1.799409
# 104         1.54              -1.832395
# 105         1.55              -1.865649
# 106         1.56              -1.899166
# 107         1.57              -1.932939
# 108         1.58              -1.966963
# 109         1.59              -2.001231
# 110         1.60              -2.035737
# 111         1.61              -2.070472
# 112         1.62              -2.105432
# 113         1.63              -2.140609
# 114         1.64              -2.175996
# 115         1.65              -2.211586
# 116         1.66              -2.247372
# 117         1.67              -2.283346
# 118         1.68              -2.319503
# 119         1.69              -2.355834
# 120         1.70              -2.392331
# 121         1.71              -2.428989
# 122         1.72              -2.465799
# 123         1.73              -2.502754
# 124         1.74              -2.539848
# 125         1.75              -2.577071
# 126         1.76              -2.614418
# 127         1.77              -2.651880
# 128         1.78              -2.689451
# 129         1.79              -2.727123
# 130         1.80              -2.764889
# 131         1.81              -2.802742
# 132         1.82              -2.840675
# 133         1.83              -2.878681
# 134         1.84              -2.916752
# 135         1.85              -2.954882
# 136         1.86              -2.993065
# 137         1.87              -3.031292
# 138         1.88              -3.069559
# 139         1.89              -3.107857
# 140         1.90              -3.146182
# 141         1.91              -3.184525
# 142         1.92              -3.222882
# 143         1.93              -3.261246
# 144         1.94              -3.299610
# 145         1.95              -3.337970
# 146         1.96              -3.376320
# 147         1.97              -3.414653
# 148         1.98              -3.452964
# 149         1.99              -3.491249
# 150         2.00              -3.529501
# 151         2.01              -3.567716
# 152         2.02              -3.605888
# 153         2.03              -3.644014
# 154         2.04              -3.682087
# 155         2.05              -3.720105
# 156         2.06              -3.758061
# 157         2.07              -3.795953
# 158         2.08              -3.833776
# 159         2.09              -3.871526
# 160         2.10              -3.909200
# 161         2.11              -3.946792
# 162         2.12              -3.984301
# 163         2.13              -4.021723
# 164         2.14              -4.059055
# 165         2.15              -4.096292
# 166         2.16              -4.133433
# 167         2.17              -4.170475
# 168         2.18              -4.207415
# 169         2.19              -4.244251
# 170         2.20              -4.280979
# 171         2.21              -4.317598
# 172         2.22              -4.354106
# 173         2.23              -4.390500
# 174         2.24              -4.426779
# 175         2.25              -4.462941
# 176         2.26              -4.498984
# 177         2.27              -4.534906
# 178         2.28              -4.570707
# 179         2.29              -4.606385
# 180         2.30              -4.641939
# 181         2.31              -4.677367
# 182         2.32              -4.712669
# 183         2.33              -4.747844
# 184         2.34              -4.782891
# 185         2.35              -4.817809
# 186         2.36              -4.852598
# 187         2.37              -4.887256
# 188         2.38              -4.921785
# 189         2.39              -4.956183
# 190         2.40              -4.990450
# 191         2.41              -5.024586
# 192         2.42              -5.058591
# 193         2.43              -5.092465
# 194         2.44              -5.126208
# 195         2.45              -5.159819
# 196         2.46              -5.193300
# 197         2.47              -5.226650
# 198         2.48              -5.259870
# 199         2.49              -5.292961
# 200         2.50              -5.325921
# 201         2.51              -5.358753
# 202         2.52              -5.391456
# 203         2.53              -5.424031
# 204         2.54              -5.456480
# 205         2.55              -5.488801
# 206         2.56              -5.520997
# 207         2.57              -5.553067
# 208         2.58              -5.585014
# 209         2.59              -5.616836
# 210         2.60              -5.648537
# 211         2.61              -5.680115
# 212         2.62              -5.711573
# 213         2.63              -5.742911
# 214         2.64              -5.774130
# 215         2.65              -5.805231
# 216         2.66              -5.836215
# 217         2.67              -5.867084
# 218         2.68              -5.897837
# 219         2.69              -5.928478
# 220         2.70              -5.959006
# 221         2.71              -5.989422
# 222         2.72              -6.019728
# 223         2.73              -6.049926
# 224         2.74              -6.080015
# 225         2.75              -6.109998
# 226         2.76              -6.139875
# 227         2.77              -6.169648
# 228         2.78              -6.199317
# 229         2.79              -6.228885
# 230         2.80              -6.258352
# 231         2.81              -6.287720
# 232         2.82              -6.316989
# 233         2.83              -6.346161
# 234         2.84              -6.375238
# 235         2.85              -6.404220
# 236         2.86              -6.433108
# 237         2.87              -6.461905
# 238         2.88              -6.490610
# 239         2.89              -6.519226
# 240         2.90              -6.547753
# 241         2.91              -6.576193
# 242         2.92              -6.604547
# 243         2.93              -6.632816
# 244         2.94              -6.661001
# 245         2.95              -6.689104
# 246         2.96              -6.717126
# 247         2.97              -6.745067
# 248         2.98              -6.772930
# 249         2.99              -6.800715
# 250         3.00              -6.828423
# 251         3.01              -6.856055
# 252         3.02              -6.883614
# 253         3.03              -6.911099
# 254         3.04              -6.938512
# 255         3.05              -6.965854
# 256         3.06              -6.993126
# 257         3.07              -7.020330
# 258         3.08              -7.047465
# 259         3.09              -7.074534
# 260         3.10              -7.101538
# 261         3.11              -7.128477
# 262         3.12              -7.155352
# 263         3.13              -7.182165
# 264         3.14              -7.208916
# 265         3.15              -7.235607
# 266         3.16              -7.262239
# 267         3.17              -7.288812
# 268         3.18              -7.315327
# 269         3.19              -7.341786
# 270         3.20              -7.368190
# 271         3.21              -7.394539
# 272         3.22              -7.420833
# 273         3.23              -7.447076
# 274         3.24              -7.473266
# 275         3.25              -7.499405
# 276         3.26              -7.525494
# 277         3.27              -7.551533
# 278         3.28              -7.577524
# 279         3.29              -7.603468
# 280         3.30              -7.629364
# 281         3.31              -7.655215
# 282         3.32              -7.681020
# 283         3.33              -7.706781
# 284         3.34              -7.732499
# 285         3.35              -7.758174
# 286         3.36              -7.783806
# 287         3.37              -7.809397
# 288         3.38              -7.834948
# 289         3.39              -7.860459
# 290         3.40              -7.885930
# 291         3.41              -7.911363
# 292         3.42              -7.936759
# 293         3.43              -7.962117
# 294         3.44              -7.987439
# 295         3.45              -8.012725
# 296         3.46              -8.037976
# 297         3.47              -8.063193
# 298         3.48              -8.088376
# 299         3.49              -8.113525
